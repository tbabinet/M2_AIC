# %%
import torch as th
import torch.nn as nn
import random
import os
import sys
import nltk
from collections import Counter

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/tp-
# [nltk_data]     home008/tbabine/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
class Model(nn.Module):
    def __init__(self, nb_cells, input_dim, hidden_size, vocab_size, embeddings_dim): 
        super(Autoencoder, self).__init__()
        self.gru = nn.GRU(input_dim, hidden_size, nb_cells)
        self.embeddings = nn.embeddings()
        
        
    def forward(self, x):

# %%
directory = "rap/Pnl"
all_sons = ""
for album in os.listdir(directory):
    dir_album = "{}/{}".format(directory, album)
    for son in os.listdir(dir_album):
        adr = "{}/{}".format(dir_album,son)
        with open(adr, 'rb') as f:
            data = f.read()
            decoded_data = data.decode('latin-1')
            all_sons+=decoded_data

# %%
token = nltk.word_tokenize(all_sons.lower())

# %%
cntr = Counter(token)

# %%
print(cntr)
# Out:
# Counter({',': 4362, 'la': 1208, 'pas': 714, 'le': 641, 'de': 521, 'dans': 507, 'à': 503, 'les': 484, 'on': 447, "'": 376, 'que': 371, '(': 370, ')': 370, 'ouais': 355, '[': 342, ']': 342, ':': 334, "j'suis": 284, 'ma': 283, 'et': 280, 'un': 274, "j'ai": 271, 'comme': 260, 'tu': 253, 'en': 243, 'je': 241, 'pour': 238, 'du': 226, 'a': 213, 'mon': 211, 'plus': 207, 'sur': 206, "c'est": 192, 'des': 186, 'ademo': 185, 'ça': 182, 'vie': 181, 'est': 180, 'qui': 157, 'au': 150, 'couplet': 147, 'si': 136, '?': 132, 'refrain': 129, 'n.o.s': 125, "j'me": 120, 'mais': 113, 'me': 110, 'tout': 110, 'y': 103, 'une': 102, 'ta': 97, 'quand': 97, 'mes': 96, 'moi': 95, 'bang': 95, 'igo': 94, "qu'on": 85, 'se': 84, 'fait': 81, 'ton': 80, 'ce': 80, 'faut': 78, "j'fais": 78, 'nous': 77, 'ounga': 77, 'khey': 76, 'haine': 75, 'gros': 74, 'rien': 73, 'c\x9cur': 71, "''": 70, 'sous': 70, 'monde': 70, 'y-yeah': 70, '1': 68, '``': 68, 'avec': 68, 'temps': 68, '2': 67, 'trop': 66, 'même': 66, 'te': 66, 'qu': 65,
# ...
